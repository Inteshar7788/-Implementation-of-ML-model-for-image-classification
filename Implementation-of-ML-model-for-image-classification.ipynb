# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

# %%
data_train_path = 'Fruits_Vegetables/train'
data_test_path = 'Fruits_Vegetables/test'
data_val_path = 'Fruits_Vegetables/validation'

# %%
img_width = 180
img_height =180

# %%
data_train = tf.keras.utils.image_dataset_from_directory(
    data_train_path,
    shuffle=True,
    image_size=(img_width, img_height),
    batch_size=32,
    validation_split=False)
# Out:
# Found 3115 files belonging to 36 classes.

# %%
data_cat = data_train.class_names

# %%
data_cat
# Out:
# ['apple',
#  'banana',
#  'beetroot',
#  'bell pepper',
#  'cabbage',
#  'capsicum',
#  'carrot',
#  'cauliflower',
#  'chilli pepper',
#  'corn',
#  'cucumber',
#  'eggplant',
#  'garlic',
#  'ginger',
#  'grapes',
#  'jalepeno',
#  'kiwi',
#  'lemon',
#  'lettuce',
#  'mango',
#  'onion',
#  'orange',
#  'paprika',
#  'pear',
#  'peas',
#  'pineapple',
#  'pomegranate',
#  'potato',
#  'raddish',
#  'soy beans',
#  'spinach',
#  'sweetcorn',
#  'sweetpotato',
#  'tomato',
#  'turnip',
#  'watermelon']

# %%
data_val = tf.keras.utils.image_dataset_from_directory(data_val_path,
                                                       image_size=(img_height,img_width),
                                                       batch_size=32,
                                                        shuffle=False,
                                                       validation_split=False)
# Out:
# Found 351 files belonging to 36 classes.

# %%
data_test = tf.keras.utils.image_dataset_from_directory(
data_test_path,
    image_size=(img_height,img_width),
    shuffle=False,
    batch_size=32,
    validation_split=False
)
# Out:
# Found 359 files belonging to 36 classes.

# %%
plt.figure(figsize=(10,10))
for image, labels in data_train.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.title(data_cat[labels[i]])
        plt.axis('off')

# %%
from tensorflow.keras.models import Sequential

# %%
data_train
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
model = Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32,3, padding='same',activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dropout(0.2),
    layers.Dense(128),
    layers.Dense(len(data_cat))
                  
])

# %%
model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
epochs_size = 25
history = model.fit(data_train, validation_data=data_val, epochs=epochs_size)
# Out:
# Epoch 1/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 45s 399ms/step - accuracy: 0.0471 - loss: 3.6185 - val_accuracy: 0.3533 - val_loss: 2.5914
# Epoch 2/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 38s 373ms/step - accuracy: 0.2649 - loss: 2.5848 - val_accuracy: 0.6752 - val_loss: 1.3919
# Epoch 3/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 38s 375ms/step - accuracy: 0.5013 - loss: 1.7638 - val_accuracy: 0.8405 - val_loss: 0.7263
# Epoch 4/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 37s 345ms/step - accuracy: 0.6974 - loss: 1.0393 - val_accuracy: 0.9231 - val_loss: 0.3891
# Epoch 5/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 62s 609ms/step - accuracy: 0.8677 - loss: 0.4597 - val_accuracy: 0.9402 - val_loss: 0.3304
# Epoch 6/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 66s 677ms/step - accuracy: 0.9431 - loss: 0.2471 - val_accuracy: 0.9487 - val_loss: 0.3127
# Epoch 7/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 66s 666ms/step - accuracy: 0.9674 - loss: 0.1734 - val_accuracy: 0.9544 - val_loss: 0.3817
# Epoch 8/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 76s 760ms/step - accuracy: 0.9765 - loss: 0.1374 - val_accuracy: 0.9544 - val_loss: 0.3588
# Epoch 9/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 73s 644ms/step - accuracy: 0.9854 - loss: 0.0998 - val_accuracy: 0.9544 - val_loss: 0.3863
# Epoch 10/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 127s 1s/step - accuracy: 0.9814 - loss: 0.0974 - val_accuracy: 0.9430 - val_loss: 0.4432
# Epoch 11/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 113s 1s/step - accuracy: 0.9820 - loss: 0.1003 - val_accuracy: 0.9430 - val_loss: 0.4099
# Epoch 12/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 120s 1s/step - accuracy: 0.9840 - loss: 0.0937 - val_accuracy: 0.9516 - val_loss: 0.4012
# Epoch 13/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 134s 1s/step - accuracy: 0.9792 - loss: 0.0877 - val_accuracy: 0.9516 - val_loss: 0.3790
# Epoch 14/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 119s 1s/step - accuracy: 0.9860 - loss: 0.0675 - val_accuracy: 0.9487 - val_loss: 0.3542
# Epoch 15/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 113s 1s/step - accuracy: 0.9867 - loss: 0.0646 - val_accuracy: 0.9487 - val_loss: 0.4346
# Epoch 16/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 118s 1s/step - accuracy: 0.9819 - loss: 0.0893 - val_accuracy: 0.9487 - val_loss: 0.3953
# Epoch 17/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 124s 989ms/step - accuracy: 0.9820 - loss: 0.0815 - val_accuracy: 0.9487 - val_loss: 0.3627
# Epoch 18/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 110s 1s/step - accuracy: 0.9854 - loss: 0.0661 - val_accuracy: 0.9516 - val_loss: 0.3876
# Epoch 19/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 96s 975ms/step - accuracy: 0.9797 - loss: 0.0813 - val_accuracy: 0.9630 - val_loss: 0.3421
# Epoch 20/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 110s 1s/step - accuracy: 0.9831 - loss: 0.0575 - val_accuracy: 0.9573 - val_loss: 0.3357
# Epoch 21/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 145s 1s/step - accuracy: 0.9883 - loss: 0.0597 - val_accuracy: 0.9573 - val_loss: 0.3339
# Epoch 22/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 120s 1s/step - accuracy: 0.9885 - loss: 0.0441 - val_accuracy: 0.9630 - val_loss: 0.2937
# Epoch 23/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 118s 1s/step - accuracy: 0.9900 - loss: 0.0370 - val_accuracy: 0.9601 - val_loss: 0.2669
# Epoch 24/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 120s 1s/step - accuracy: 0.9887 - loss: 0.0378 - val_accuracy: 0.9573 - val_loss: 0.3535
# Epoch 25/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 116s 1s/step - accuracy: 0.9861 - loss: 0.0466 - val_accuracy: 0.9516 - val_loss: 0.3510

# %%
epochs_range = range(epochs_size)
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(epochs_range,history.history['accuracy'],label = 'Training Accuracy')
plt.plot(epochs_range, history.history['val_accuracy'],label = 'Validation Accuracy')
plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(epochs_range,history.history['loss'],label = 'Training Loss')
plt.plot(epochs_range, history.history['val_loss'],label = 'Validation Loss')
plt.title('Loss')
# Out:
# Text(0.5, 1.0, 'Loss')

# %%
image = 'Corn.jpg'
image = tf.keras.utils.load_img(image, target_size=(img_height,img_width))
img_arr = tf.keras.utils.array_to_img(image)
img_bat=tf.expand_dims(img_arr,0)

# %%
predict = model.predict(img_bat)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step

# %%
score = tf.nn.softmax(predict)

# %%
print('Veg/Fruit in image is {} with accuracy of {:0.2f}'.format(data_cat[np.argmax(score)],np.max(score)*100))
# Out:
# Veg/Fruit in image is corn with accuracy of 87.34

# %%
model.save('Image_classify.keras')
